# %% [markdown]
# # Исследование популярного музыкального стримингового сервиса "МиФаСоль"
#
# Сервис расширяет работу с новыми артистами и музыкантами, в связи с чем возникла задача -- правильно классифицировать новые музыкальные треки, чтобы улучшить работу рекомендательной системы.
#
#
# ## 1.Описание данных
#
# Данные
#
# - train.csv - информация (~40000) музыкальных треках, которые будут использоваться в качестве обучающих данных.
#
# - test.csv - информация (~10000) музыкальных треках, которые будут использоваться в качестве тестовых данных. Ваша задача - предсказать значение 'music_genre' для каждого трека из этого датасета.
#
#     Описание полей данных:
#
# **instance_id** -Уникальный идентификатор трека
#
# **track_name** - Название трека
#
# **acousticness** - Мера уверенности от 0,0 до 1,0 в том, что трек является акустическим. 1,0 означает высокую степень уверенности в том, что трек является акустическим
#
# **danceability** - Танцевальность описывает, насколько трек подходит для танцев, основываясь на сочетании музыкальных элементов, включая темп, стабильность ритма, силу ударов и общую регулярность. Значение 0,0 означает наименьшую танцевальность, а 1,0 - наибольшую танцевальность
#
# **duration_ms** - Продолжительность трека в миллисекундах
#
# **energy** - Энергия это показатель от 0,0 до 1,0, представляющий собой меру интенсивности и активности. Как правило, энергичные композиции ощущаются как быстрые, громкие и шумные. Например, дэт-метал обладает высокой энергией, в то время как прелюдия Баха имеет низкую оценку этого параметра
#
# **instrumentalness** - Определяет, содержит ли трек вокал. Звуки "Ooh" и "aah" в данном контексте рассматриваются как инструментальные. Рэп или разговорные треки явно являются "вокальными". Чем ближе значение инструментальности к 1,0, тем больше вероятность того, что трек не содержит вокала
#
# **key** - базовый ключ (нота) произведения
#
# **liveness** - Определяет присутствие аудитории в записи. Более высокие значения liveness означают увеличение вероятности того, что трек был исполнен вживую. Значение выше 0,8 обеспечивает высокую вероятность того, что трек исполняется вживую
#
# **loudness** - Общая громкость трека в децибелах (дБ)
#
# **mode** - Указывает на модальность (мажорную или минорную) трека
#
# **speechiness** - Речевой характер определяет наличие в треке разговорной речи. Чем более исключительно речевой характер носит запись (например, ток-шоу, аудиокнига, поэзия), тем ближе значение атрибута к 1,0. Значения выше 0,66 характеризуют треки, которые, вероятно, полностью состоят из разговорной речи. Значения от 0,33 до 0,66 характеризуют треки, которые могут содержать как музыку, так и речь, как в виде фрагментов, так и в виде слоев, включая такие случаи, как рэп-музыка. Значения ниже 0,33, скорее всего, представляют музыку и другие неречевые треки
#
# **tempo** - Темп трека в ударах в минуту (BPM). В музыкальной терминологии темп представляет собой скорость или темп данного произведения и напрямую зависит от средней продолжительности тактов
#
# **obtained_date** - дата загрузки в сервис
#
# **valence** - Показатель от 0,0 до 1,0, характеризующий музыкальный позитив, передаваемый треком. Композиции с высокой валентностью звучат более позитивно (например, радостно, весело, эйфорично), а композиции с низкой валентностью - более негативно (например, грустно, депрессивно, сердито)
#
# **music_genre** - Музыкальный жанр трека
#
#     Последнее значение и является целью нашей работы.

# %%
# !pip install scikit-learn==1.1.3 -q
# !pip install phik
# Out:
# Requirement already satisfied: phik in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (0.12.3)
# Requirement already satisfied: numpy>=1.18.0 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from phik) (1.26.3)
# Requirement already satisfied: scipy>=1.5.2 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from phik) (1.12.0)
# Requirement already satisfied: pandas>=0.25.1 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from phik) (2.2.0)
# Requirement already satisfied: matplotlib>=2.2.3 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from phik) (3.8.2)
# Requirement already satisfied: joblib>=0.14.1 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from phik) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2.3->phik) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2.3->phik) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2.3->phik) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2.3->phik) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2.3->phik) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2.3->phik) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2.3->phik) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2.3->phik) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2.3->phik) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.1->phik) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.1->phik) (2023.4)
# Requirement already satisfied: zipp>=3.1.0 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=2.2.3->phik) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->phik) (1.16.0)

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (1.2.2)
# Requirement already satisfied: graphviz in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from catboost) (3.8.2)
# Requirement already satisfied: numpy>=1.16.0 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from catboost) (1.26.3)
# Requirement already satisfied: pandas>=0.24 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from catboost) (2.2.0)
# Requirement already satisfied: scipy in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from catboost) (1.12.0)
# Requirement already satisfied: plotly in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from catboost) (5.18.0)
# Requirement already satisfied: six in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (6.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from plotly->catboost) (8.2.3)
# Requirement already satisfied: zipp>=3.1.0 in /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->catboost) (3.17.0)

# %%
#Импортируем необходимые нам в работе инструменты
import pandas as pd
import matplotlib.pyplot as plt
import phik
from phik.report import plot_correlation_matrix
from phik import report
import seaborn as sns
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier 
from sklearn.linear_model import LogisticRegression
from catboost import CatBoostClassifier, cv, Pool
from sklearn.compose import make_column_selector, make_column_transformer, ColumnTransformer
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from numpy.random import RandomState 
state=RandomState(12345)
from sklearn.metrics import f1_score

# %%
#Подгружаем данные 
data_train = pd.read_csv('/Users/mariaspartalan/Desktop/готовые проекты/мифасоль/train.csv')
data_test = pd.read_csv('/Users/mariaspartalan/Desktop/готовые проекты/мифасоль/test.csv')

# %% [markdown]
# **Промежуточный вывод**
#
# Данные выгружены успешно.
#
# 40000 объектов в обучающей выборке и 10000 в тестовой.

# %% [markdown]
# ## 2.Предобработка и исследовательский анализ данных
#
# Рассмотрим данные поподробннее

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   instance_id       40000 non-null  int64
#  1   track_name        29262 non-null  object
#  2   popularity        36078 non-null  float64
#  3   acousticness      40000 non-null  float64
#  4   danceability      37963 non-null  float64
#  5   duration_ms       40000 non-null  float64
#  6   energy            40000 non-null  float64
#  7   instrumentalness  40000 non-null  float64
#  8   key               38577 non-null  object
#  9   liveness          40000 non-null  float64
#  10  loudness          40000 non-null  float64
#  11  mode              38147 non-null  object
#  12  speechiness       40000 non-null  float64
#  13  tempo             40000 non-null  object
#  14  obtained_date     33781 non-null  object
#  15  valence           40000 non-null  float64
#  16  music_genre       40000 non-null  object
# dtypes: float64(10), int64(1), object(6)
# memory usage: 5.2+ MB

# %%
data_train.head()
# Out:
#    instance_id                   track_name  popularity  acousticness  \
# 0         4919                 By Your Side        33.0      0.000718
# 1        16096                          NaN        55.0      0.064700
# 2        43825  Symphony No. 6: VI. Allegro        39.0      0.931000
# 3         4331                          NaN        56.0      0.012300
# 4        21371                Shoe Shopping        52.0      0.580000
#
#    danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 0         0.501         -1.0   0.935          0.020100   G#    0.0831
# 1         0.282     288333.0   0.738          0.014200    C    0.2900
# 2         0.364     115240.0   0.349          0.940000  NaN    0.1100
# 3         0.332     234638.0   0.847          0.000027    B    0.2970
# 4         0.716     221640.0   0.614          0.000014    G    0.1600
#
#    loudness   mode  speechiness              tempo obtained_date  valence  \
# 0    -5.566  Minor       0.1570            144.922         4-Apr   0.1880
# 1    -5.566  Major       0.0324            126.914           NaN   0.2110
# 2   -13.279    NaN       0.0321  65.42699999999999         4-Apr   0.0891
# 3    -4.513  Minor       0.0910              67.23         5-Apr   0.3920
# 4    -7.099  Major       0.0360             88.006         4-Apr   0.6800
#
#    music_genre
# 0   Electronic
# 1  Alternative
# 2    Classical
# 3   Electronic
# 4      Country

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   instance_id       10000 non-null  int64
#  1   track_name        7388 non-null   object
#  2   popularity        8987 non-null   float64
#  3   acousticness      10000 non-null  float64
#  4   danceability      9477 non-null   float64
#  5   duration_ms       10000 non-null  float64
#  6   energy            10000 non-null  float64
#  7   instrumentalness  10000 non-null  float64
#  8   key               9673 non-null   object
#  9   liveness          10000 non-null  float64
#  10  loudness          10000 non-null  float64
#  11  mode              9518 non-null   object
#  12  speechiness       10000 non-null  float64
#  13  tempo             10000 non-null  object
#  14  obtained_date     8419 non-null   object
#  15  valence           10000 non-null  float64
# dtypes: float64(10), int64(1), object(5)
# memory usage: 1.2+ MB

# %% [markdown]
# ***Задачи***
#
# Работа с пропусками.
#
#
# - Рассмотреть данные по дате
# - изучить пропуски в категориальных значениях
#   - track_name
#   - key
#   - mode
# - изучить пропуски в количественных значениях
#   - popularity
#   - danceability
#   - tempo рассмотреть данные. Почему они представлены НЕ в числовом фомате. Исправить на нужные.
#
# Проверка на дубликаты

# %% [markdown]
# В наших данных для обучения содержится информация о 4000о треках. Это композиции в 10 жанрах. Данные распределены примерно одинаково.

# %% [markdown]
# ### Обработка пропусков и аномалий
# ## 2.1 Obtained date

# %%
#Изучаем время
data_test['obtained_date'].unique()
# Out:
# array(['4-Apr', '3-Apr', nan, '5-Apr', '1-Apr'], dtype=object)

# %%
data_train['obtained_date'].unique()
# Out:
# array(['4-Apr', nan, '5-Apr', '3-Apr', '1-Apr', '0/4'], dtype=object)

# %%
data_train.query('obtained_date == "0/4"')
# Out:
#        instance_id track_name  popularity  acousticness  danceability  \
# 11319        29297    Imma Be        61.0         0.184         0.619
#
#        duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 11319     257560.0   0.539               0.0   C     0.288      -6.9  Major
#
#        speechiness tempo obtained_date  valence music_genre
# 11319        0.387     ?           0/4    0.424         Rap

# %% [markdown]
# Большая часть данных была добавлена в течении 4 дней. Эти данные не являются ценными.
#
# Удалим этот признак.

# %%
#Удаляем признак obtained_date
data_train = data_train.drop('obtained_date', axis=1)
data_test = data_test.drop('obtained_date', axis=1)

# %% [markdown]
# ### 2.2 track_name

# %% [markdown]
# Приведем все названия в единый вид. Все переведем в строчный регистр, уберем артикли и удалим лишние пробелы.

# %%
print('было', data_train['track_name'].nunique())
data_train['track_name'] = data_train['track_name'].str.lower().replace(['the', 'a'], '').str.strip()
print('стало', data_train['track_name'].nunique())
# Out:
# было 26018
# стало 25765

# %%
data_train['track_name'].value_counts()
# Out:
# track_name
# home                                                           12
# intro                                                           9
# fire                                                            9
# gravity                                                         8
# blue                                                            8
#                                                                ..
# lady lay down                                                   1
# love me or leave me alone (feat. karen fairchild)               1
# tall, tall trees                                                1
# finger                                                          1
# floyd mayweather (feat. travis scott, gucci mane and gunna)     1
# Name: count, Length: 25765, dtype: int64

# %%
print('было', data_test['track_name'].nunique())
data_test['track_name'] = data_test['track_name'].str.lower().replace('the', '').str.strip()
print('стало', data_test['track_name'].nunique())
# Out:
# было 7123
# стало 7094

# %%
data_train['track_name'] = data_train['track_name'].fillna('no_name')
data_test['track_name'] = data_test['track_name'].fillna('no_name')

# %% [markdown]
# ### 2.3 кey

# %%
#Смотрим уникальные значения key в train-e
data_train['key'].unique()
# Out:
# array(['G#', 'C', nan, 'B', 'G', 'D', 'E', 'C#', 'A', 'F', 'A#', 'F#',
#        'D#'], dtype=object)

# %%
#Смотрим уникальные значения key в teste-e
data_test['key'].unique()
# Out:
# array(['G', 'A', 'C#', 'D', 'F#', 'F', 'A#', 'C', 'B', 'G#', 'E', 'D#',
#        nan], dtype=object)

# %% [markdown]
# Здесь все корректно, 7 нот и 5 полутонов.

# %%
data_train['key'].hist(bins=12)
plt.title('Распределение композиций по заглавной ноте')
plt.show()

# %%
data_train['key'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Распределение композиций по заглавной ноте')
plt.show()

# %% [markdown]
# Больше всего треков в тональностях Соль и До. Меньше всего в Ре-Диез.

# %% [markdown]
# ### 2.4 mode

# %%
#Изучаем и причесываем mode в train-е
print(data_train['mode'].unique())
print()
print(data_test['mode'].unique())
# Out:
# ['Minor' 'Major' nan]
#
# ['Major' nan 'Minor']

# %% [markdown]
# <div class="alert alert-info">
# for x in [data_train, data_test]:
#     x['mode'] = x['mode'].str.replace('#', '').str.lower().fillna('na')
#     print(x['mode'].unique())
#     print()

# %%
data_train['mode'].hist(bins=2)
plt.title('Распределение композиций по модальности')
plt.show()

# %%
data_train['mode'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Распределение композиций по модальности')
plt.show()

# %% [markdown]
# Треков в мажорной тональности почти в 2 раза больше.

# %% [markdown]
# ### 2.5 music_genre

# %%
data_train['music_genre'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Распределение композиций по жанру')
plt.show()

# %% [markdown]
# В наших данных для обучения содержится информация о 40000 треках. Это композиции в 10 жанрах. Данные распределены примерно одинаково.

# %% [markdown]
# ### 2.6 danceability

# %%
data_train.boxplot(column='danceability')
plt.show()

# %% [markdown]
# Есть выбросы. Композиции с танцевальностью меньше 0.1.
#
# Рассмотрим их повнимательнее.

# %%
data_train.query('danceability < 0.1').head(50)
# Out:
#       instance_id                                         track_name  \
# 49           7045          too dreadful a practice for this open air
# 121          1697                                     oxygene, pt. 1
# 179         44129         cavalleria rusticana: symphonic intermezzo
# 352         43592                                  canon in d, p. 37
# 411         43771  the road goes ever on... pt. 2 / "in dreams" (...
# 489         41598                                            no_name
# 636          7171                                             kizuna
# 710         45517  sibelius: violin concerto in d minor, op. 47: ...
# 886         45244                                            no_name
# 923          6392                                            no_name
# 1089        43734  the return of the king (feat. sir james galway...
# 1128        43897  gorecki: symphony no. 3 op. 36, "symphony of s...
# 1263        15301                                  dissolving clouds
# 2154        44328                                            no_name
# 2328        41232                                            no_name
# 2329        10619                                        heavensturn
# 2389        45506                                            no_name
# 2470        42925                               roots and beginnings
# 2800        41864                    entry of the gods into valhalla
# 2814        41449  symphony no.8 in b minor, d.759 - "unfinished"...
# 3175        45687  belshazzar's feast, js 48: act ii: prelude: no...
# 3455        43617                                            no_name
# 3584        45325  la nativité du seigneur: 7. jésus accepte la s...
# 3697        44242                                            no_name
# 3802        41213                                            no_name
# 3896        43088                                        first dream
# 4141        44487                                            no_name
# 4158        43747                                            no_name
# 4341        44011  one of the dúnedain / "evenstar" (feat. isabel...
# 4442        41971  concerto in a major for clarinet and orchestra...
# 4490        44159                                            no_name
# 4527        45182                     in the steppes of central asia
# 4983        43198  suite for cello solo no.1 in g major, bwv 1007...
# 5245         7023                 aerith's theme (final fantasy vii)
# 5561        41735        ave, verum corpus: ave, verum corpus - live
# 5668        42299                                          rivendell
# 5730        43926  pastorale, op. 50 (version for orchestra): iii...
# 5828        45194                                            no_name
# 5929        45880                                            no_name
# 5952        44894                                      many meetings
# 6004        44830                                         khazad-dûm
# 6446        41494          colonial song (version for wind ensemble)
# 6519        44648                                 isengard unleashed
# 7074        41052                                            no_name
# 7203        43803                  appalachian spring: iii. moderato
# 7445        41055                                       mina/dracula
# 7480        44595  thaïs / act 2: méditation (arr. for violin and...
# 7491        43484                                            no_name
# 7610        42870                                               dawn
# 7657         8416                                     vegeta's theme
#
#       popularity  acousticness  danceability  duration_ms   energy  \
# 49          17.0        0.9110        0.0828      99809.0  0.24600
# 121         41.0        0.7720        0.0822     460640.0  0.29700
# 179         29.0        0.6390        0.0800     221453.0  0.05800
# 352         26.0        0.6070        0.0946     271413.0  0.17300
# 411         36.0        0.9610        0.0772     221227.0  0.14300
# 489         26.0        0.9570        0.0755     303067.0  0.01630
# 636          NaN        0.7570        0.0882     154373.0  0.30600
# 710         29.0        0.9490        0.0957     529387.0  0.13100
# 886         30.0        0.9820        0.0630      68600.0  0.05800
# 923         15.0        0.7770        0.0984     181533.0  0.40600
# 1089        39.0        0.9170        0.0754     614267.0  0.06930
# 1128        37.0        0.7220        0.0813     272560.0  0.14100
# 1263        40.0        0.9870        0.0644     268051.0  0.04630
# 2154        42.0        0.9490        0.0716     634133.0  0.05990
# 2328        50.0        0.9620        0.0727     398827.0  0.01850
# 2329        15.0        0.9570        0.0952     266539.0  0.14700
# 2389        38.0        0.9740        0.0607     382320.0  0.02100
# 2470        43.0        0.8540        0.0819     391453.0  0.13400
# 4341   70.07300000000001   0.0326   Classical
# 4442             173.919   0.0394   Classical
# 4490              84.694   0.0328   Classical
# 4527                   ?   0.0384   Classical
# 4983              82.134   0.0564   Classical
# 5245              78.835   0.0385       Anime
# 5561              73.436   0.0339   Classical
# 5668               86.93   0.0364   Classical
# 5730              87.602   0.0372   Classical
# 5828             174.446   0.0475   Classical
# 5929              59.297   0.0310   Classical
# 5952              64.791   0.0359   Classical
# 6004              80.065   0.0347   Classical
# 6446              83.529   0.0368   Classical
# 6519              76.893   0.0616   Classical
# 7074              75.767   0.0348   Classical
# 7203             177.179   0.0346   Classical
# 7445               80.83   0.0324   Classical
# 7480               69.51   0.0387   Classical
# 7491              73.979   0.0369   Classical
# 7610              52.076   0.0461   Classical
# 7657   84.78299999999999   0.1480       Anime

# %%
print('Композиций с танцевальностью меньше 0.1:', len(data_train.loc[((data_train['danceability'] <= 0.1))]))
# Out:
# Композиций с танцевальностью меньше 0.1: 225

# %% [markdown]
# Судя по названию, большинство таких композиций это классическая музыка и концерты. В таком случае, это информативная история. От таких выбросов избавляться не будем.
#
# А вот пропуски заполним медианным значением.

# %%
#Заполняем пропуски danceability
for x in [data_train, data_test]:
    x['danceability'] = x['danceability'].fillna(x['danceability'].median())

# %%
data_train['danceability'].hist(bins=40, range= (0, 1))
plt.title('Распределение по танцевальности')
plt.show()

# %% [markdown]
# ### 2.7 popularity

# %%
data_train.boxplot(column='popularity')
plt.show()
data_train['popularity'].describe()
# Out:
# count    36078.000000
# mean        44.180969
# std         15.550792
# min          0.000000
# 25%         34.000000
# 50%         45.000000
# 75%         56.000000
# max         99.000000
# Name: popularity, dtype: float64

# %% [markdown]
# Есть выбросы. Треки с популярностью больше 85 и меньше 0. Рассмотрим внимательнее.

# %%
data_train.query('popularity > 85').head(50)
# Out:
#        instance_id                                      track_name  \
# 52            1105  taki taki (with selena gomez, ozuna & cardi b)
# 796          47036                                        splashin
# 1223         50206              everybody dies in their nightmares
# 2826         49244                                         no_name
# 4744         39384                                         natural
# 6595         28481                                        splashin
# 6878         27745                      falling down - bonus track
# 8562         27234                                         no_name
# 8895         48019                                    middle child
# 9168         26592                                    pure cocaine
# 9323         49845                                            sad!
# 11288        27321                 ric flair drip (& metro boomin)
# 12268        30836                                   nice for what
# 12897        26349                                    i fall apart
# 13085        47644                                  jocelyn flores
# 13138        30569                                         no_name
# 13571        26647                          i love it (& lil pump)
# 13644        26556       praise the lord (da shine) (feat. skepta)
# 14470        26550                  fuck love (feat. trippie redd)
# 16337        29146                                         no_name
# 17547        30678                            taste (feat. offset)
# 19529        27842                                         humble.
# 20347        46042       arms around you (feat. maluma & swae lee)
# 23235        29654                    psycho (feat. ty dolla $ign)
# 23485        29018                                           money
# 23597        27634                           mala (feat. anuel aa)
# 25271        50004                              wake up in the sky
# 25423        30010                                       undecided
# 25883        27490                                    keanu reeves
# 26107        29050                                      better now
# 26547        29490                             armed and dangerous
# 26754        27261                        look alive (feat. drake)
# 26980        48967                                      no stylist
# 4744                100.0   0.2200        Rock
# 6595              100.021   0.3800         Rap
# 6878   120.01299999999999   0.2730         Rap
# 8562               99.947   0.3850         Rap
# 8895              123.984   0.4630     Hip-Hop
# 9168               127.05   0.1070         Rap
# 9323               75.023   0.4730     Hip-Hop
# 11288             100.007   0.3330         Rap
# 12268   93.39399999999999   0.7570         Rap
# 12897              143.95   0.2910         Rap
# 13085  134.02100000000002   0.4370     Hip-Hop
# 13138             155.096   0.4010         Rap
# 13571             104.053   0.3290         Rap
# 13644               80.02   0.2940         Rap
# 14470             131.036   0.3290         Rap
# 16337             136.048   0.6500         Rap
# 17547              97.994   0.3420         Rap
# 19529             150.011   0.4210         Rap
# 20347             104.969   0.2880     Hip-Hop
# 23235             140.124   0.4390         Rap
# 23485             130.003   0.2190         Rap
# 23597             100.006   0.7890         Rap
# 25271              143.01   0.3670     Hip-Hop
# 25423               96.37   0.5890         Rap
# 25883                   ?   0.8160         Rap
# 26107             145.028   0.3740         Rap
# 26547             130.032   0.8450         Rap
# 26754  140.02200000000002   0.5950         Rap
# 26980             147.055   0.4980     Hip-Hop
# 28935                   ?   0.7200     Hip-Hop
# 29192  155.00799999999998   0.4460         Rap
# 30247  120.01299999999999   0.2730     Hip-Hop
# 31385  177.91299999999998   0.0827        Rock
# 31864                   ?   0.6660        Rock
# 32507             145.972   0.2740         Rap
# 32541             128.009   0.7110     Hip-Hop
# 32726                   ?   0.6380     Hip-Hop
# 33316             129.953   0.6890         Rap
# 34588             130.049   0.4300         Rap
# 35132  202.00599999999997   0.1370     Hip-Hop
# 37104              143.01   0.3670         Rap
# 39129              127.05   0.1070     Hip-Hop

# %% [markdown]
# Просто популярные Рэп, Рок, Хип-Хоп и электро композиции. Звучит "модно". Похоже на правду, оставляем.

# %%
data_train.query('popularity < 10').head(50)
# Out:
#       instance_id                                         track_name  \
# 38          13234                          i want to be - remastered
# 88          44278  les contes d'hoffmann, act ii: entr'acte - ell...
# 90          43611  fidelio, op. 72, act i: ihr könnt das leicht s...
# 236          7388                                   hangeki no yaiba
# 252         45267                    hochzeitsmarsch (wedding march)
# 263         43756                                            no_name
# 266         42482  norwegian peasant dances, op. 72: xvi. the gir...
# 268          6827  light of the evanescence (feat. the tokyo metr...
# 309         42960  fidelio, op. 72, act ii: euch werde lohn in be...
# 351         45744  the charlatan suite (arr. k. brion for wind ba...
# 441         43312                                            no_name
# 451         24361                                            no_name
# 499         45647  die zauberflöte, k. 620, act i: ist's denn auc...
# 589         45826                                    estudio sin luz
# 592         45531  das klagende lied / pt. 2: "ach spielmann, lie...
# 639         41809      ouverture in g major, twv 32:13: ii. courante
# 698         45318  les contes d'hoffmann, act i: c'est moi, coppé...
# 735         41923  eroica variations in e-flat major, op. 35: var. 8
# 742         42526                                            no_name
# 747          7098                              break 'em all (remix)
# 783         45475  serenade for string orchestra, op. 20: iii. al...
# 882         43006  arabella, op. 79, trv 263, act iii: uber seine...
# 910         42573  piano concerto no. 2 in b-flat major, op. 83: ...
# 943         45414  fidelio, op. 72, act i: mir ist so wunderbar (...
# 950         41203  falstaff, act ii pt. 1: è sogno? o realtà? (live)
# 1168        10154                           frieza vs. spirit bomb 1
# 1209        34658                      sea child - early show - live
# 1247        37690                                    te quiero igual
# 1279         6248                                                君と光
# 1314        43967  flute sonata in e-flat major, bwv 1031: ii. si...
# 1349        44174  eroica variations in e-flat major, op. 35: var. 4
# 1505        11098                                            no_name
# 1587        45169  les contes d'hoffmann, act ii: mon enfant! ma ...
# 1628        42146                                            no_name
# 1651        44571  serenade no. 1 in d major, op. 11: v. scherzo....
# 1658         5741                                            no_name
# 1705        42383                                            no_name
# 1734        41442  the firebird suite: i. introduction - ii. l'oi...
# 1745        44409  symphony no. 5 in d minor, op. 47: ii. allegre...
# 1775        44606  rusalka, op. 114, b. 203, act i: hou, hou, hou...
# 1800        43131                                            no_name
# 1841        45533                                            no_name
# 1862        41525                                            no_name
# 1890        43686  sonata op. 2 no. 1 in b minor, hwv 386a: iv. a...
# 1922        41813                                            no_name
# 1978        10115                                             mosaku
# 1999        44276                                            no_name
# 2010        45543         el decamerón negro: i. la arpa de guerrero
# 2021        41627  lieder eines fahrenden gesellen: 3. "ich hab' ...
# 2033        44673  arabella, op. 79, trv 263, act iii: sie gibt m...
#
#       popularity  acousticness  danceability  duration_ms   energy  \
# 38           3.0      0.967000         0.572     116893.0  0.55400
# 88           0.0      0.964000         0.569         -1.0  0.01790
# 90           0.0      0.754000         0.550     106013.0  0.02370
# 236          8.0      0.030500         0.362     217253.0  0.97300
# 252          0.0      0.956000         0.357     286800.0  0.39700
# 263          0.0      0.981000         0.355     144987.0  0.06130
# 266          0.0      0.994000         0.569      82493.0  0.01810
# 268          8.0      0.859000         0.139     152200.0  0.29200
# 309          0.0      0.960000         0.251     403653.0  0.08310
# 351          0.0      0.986000         0.194     120467.0  0.02790
# 441          0.0      0.972000         0.150     204307.0  0.12600
# 451          0.0      0.197000         0.462     252760.0  0.43900
# 499          0.0      0.922000         0.431     389067.0  0.12700
# 589          0.0      0.987000         0.363     181627.0  0.05340
# 592          2.0      0.969000         0.130     140040.0  0.14300
# 639          8.0      0.865000         0.569         -1.0  0.27600
# 698          0.0      0.913000         0.412      71160.0  0.01260
# 735          0.0      0.988000         0.298      54326.0  0.00532
# 742          0.0      0.947000         0.299         -1.0  0.10600
# 747          9.0      0.000163         0.620     234545.0  0.99000
# 783          8.0      0.970000         0.172     165680.0  0.03210
# 882          0.0      0.935000         0.190     111000.0  0.14800
# 910          0.0      0.987000         0.293    1018613.0  0.14200
# 943          0.0      0.955000         0.189     277080.0  0.07880
# 950          0.0      0.952000         0.313     386373.0  0.17500
# 1168         9.0      0.717000         0.126      81000.0  0.24300
# 1209         0.0      0.834000         0.552     352297.0  0.25400
# 1247         3.0      0.148000         0.532     235560.0  0.88400
# 1279         8.0      0.845000         0.572     304280.0  0.42200
# 1314         0.0      0.980000         0.319     123933.0  0.00922
# 1349         0.0      0.989000         0.527         -1.0  0.10700
# Чайковский переворачивается в ...

# %%
print('Композиция с экстремальными значениями по признакому популярность', len(data_train.loc[((data_train['popularity'] >= 85) | (data_train['popularity' ] <= 10))]))
# Out:
# Композиция с экстремальными значениями по признакому популярность 860

# %% [markdown]
# Оставляем все объекты. Пропуски заполняем медианным значением.

# %%
for x in [data_train, data_test]:
    x['popularity'] = x['popularity'].fillna(x['popularity'].median())

# %% [markdown]
# ### 2.8 tempo
#
# Количественный признак, но почему-то записан в формате строки. Выявим аномалию и исправим.

# %%
data_train['tempo'].value_counts()
# Out:
# tempo
# ?                     3979
# 120.0                   15
# 100.014                 14
# 119.985                 13
# 100.00200000000001      13
#                       ...
# 70.002                   1
# 144.458                  1
# 84.757                   1
# 158.241                  1
# 104.436                  1
# Name: count, Length: 25110, dtype: int64

# %%
data_test['tempo'].value_counts()
# Out:
# tempo
# ?                     1001
# 89.992                   5
# 99.99799999999999        5
# 100.00299999999999       5
# 140.007                  5
#                       ...
# 133.98                   1
# 113.29899999999999       1
# 104.98899999999999       1
# 104.85600000000001       1
# 101.95299999999999       1
# Name: count, Length: 7941, dtype: int64

# %% [markdown]
# Такой формат из-за значения '?'. Высчитаем медианное  заменим '?' на него.

# %%
for x in [data_train, data_test]:

    data_tempo = x.query('tempo != "?"')
    data_tempo['tempo'] = data_tempo['tempo'].astype('float64')
    med_tempo = data_tempo['tempo'].median()
    x['tempo'] = x['tempo'].replace('?', med_tempo).astype('float64')
# Out:
# /var/folders/rh/m635vnx9069_1y61mcn7n51h0000gn/T/ipykernel_76392/1165725778.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_tempo['tempo'] = data_tempo['tempo'].astype('float64')
# /var/folders/rh/m635vnx9069_1y61mcn7n51h0000gn/T/ipykernel_76392/1165725778.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_tempo['tempo'] = data_tempo['tempo'].astype('float64')

# %%
data_train.boxplot(column = 'tempo')
# Out:
# <Axes: >

# %%
print('Композиций со скоростью тактов:', len(data_train.loc[((data_train['tempo'] >= 190))]))
# Out:
# Композиций со скоростью тактов: 399

# %% [markdown]
# ### 2.9 duration

# %%
data_train.boxplot(column='duration_ms')
plt.show()
data_train['duration_ms'].describe()
# Out:
# count    4.000000e+04
# mean     2.213221e+05
# std      1.297367e+05
# min     -1.000000e+00
# 25%      1.748498e+05
# 50%      2.193200e+05
# 75%      2.686670e+05
# max      4.830606e+06
# Name: duration_ms, dtype: float64

# %%
data_train['duration_ms'].max()
# Out:
# 4830606.0

# %%
print('Композиция с аномальными значениями длительности', len(data_train.loc[((data_train['duration_ms'] >= 500000) | (data_train['popularity' ] <= 0))]))
# Out:
# Композиция с аномальными значениями длительности 1333

# %%
data_train.query('duration_ms < 0').head(50)
# Out:
#      instance_id                                         track_name  \
# 0           4919                                       by your side
# 19         12491                                            no_name
# 25         46065                                             dreams
# 27         48579                                              sorry
# 31         19239                   dead leaves and the dirty ground
# 33         26376                                             figaro
# 43         20289                                           souk eye
# 46         40617                                             always
# 51         28993                                           verbatim
# 56         22987                                        drunk drunk
# 66         49097                            mi pasado y mi presente
# 70          5755                  final boss (dillon francis remix)
# 75         34603                                            no_name
# 88         44278  les contes d'hoffmann, act ii: entr'acte - ell...
# 89         31797                                            no_name
# 96          8990                                            no_name
# 99          7345                                               gold
# 109        28645                                     where them $ @
# 122        19493                                            no_name
# 139        30243                                            someday
# 151        26567                       once upon a time (freestyle)
# 153         5922                                              finer
# 161         2687                      public making out is like ugh
# 162        50854                                            no_name
# 175        27609                                 whole lotta lovin'
# 183        11214                                            no_name
# 189        27828            hopes up (feat. dashboard confessional)
# 203        13048                                            no_name
# 213        19033                                              bleed
# 214         4462                                            no_name
# 221        16402                                   kiss with a fist
# 228        50433                                                901
# 282         7911                                            no_name
# 289        24902                       toes - greatest hits version
# 292        19220                                         on our way
# 314        30729                              rich love (with seeb)
# 324        15720                             tell me something good
# 328        12009                                        night drive
# 331        22497                                      workin' on me
# 340        37553             golden years - 2016 remastered version
# 346        29611                                            no_name
# 354        26609                            over here - feat. drake
# 368        37240                                            no_name
# 370        44818                             wayside (back in time)
# 374        13396                              down by the riverside
# 379        27799                                            no_name
# 384        43394                 academic festival overture, op. 80
# 399        23291                                             my own
# 413        37950                                        jackie blue
# 422        20878                                            no_name
#
#      popularity  acousticness  danceability  duration_ms  energy  \
# 0          33.0      0.000718         0.501         -1.0  0.9350
# 19         33.0      0.269000         0.580         -1.0  0.7480
# 25         45.0      0.394000         0.490         -1.0  0.3510
# 27         55.0      0.428000         0.870         -1.0  0.5310
# 31         46.0      0.471000         0.363         -1.0  0.6110
# 33         53.0      0.188000         0.836         -1.0  0.8120
# 43         55.0      0.430000         0.640         -1.0  0.8530
# 46         61.0      0.665000         0.408         -1.0  0.4990
# 51         61.0      0.057800         0.667         -1.0  0.4930
# 56         38.0      0.068300         0.526         -1.0  0.8810
# 66         66.0      0.494000         0.796         -1.0  0.5550
# 70         35.0      0.000991         0.673         -1.0  0.9720
# 75         64.0      0.263000         0.443         -1.0  0.7270
# 88          0.0      0.964000         0.569         -1.0  0.0179
# 89         24.0      0.086700         0.479         -1.0  0.8300
# 96         32.0      0.977000         0.669         -1.0  0.1700
# 99         24.0      0.009200         0.569         -1.0  0.9850
# 109        54.0      0.044300         0.858         -1.0  0.5250
# 122        48.0      0.000931         0.629         -1.0  0.9960
# 139        60.0      0.108000         0.600         -1.0  0.7380
# 151        59.0      0.114000         0.653         -1.0  0.9100
# 153        36.0      0.006950         0.890         -1.0  0.3990
# 161        29.0      0.335000         0.549         -1.0  0.6400
# 162        70.0      0.404000         0.629         -1.0  0.6010
# 175        58.0      0.154000         0.438         -1.0  0.3990
# 183        45.0      0.996000         0.541         -1.0  0.0112
# 189        57.0      0.024900         0.541         -1.0  0.6750
# 203        32.0      0.736000         0.785         -1.0  0.3010
# 213        52.0      0.000008         0.569         -1.0  0.9980
# 214        32.0      0.144000         0.473         -1.0  0.8910
# 221        48.0      0.002400         0.367         -1.0  0.8010
# 228        50.0      0.000778         0.879         -1.0  0.4800
# 282        22.0      0.002670         0.592         -1.0  0.9720
# 221          0.000273    D    0.0603    -5.396  Major       0.1370  107.014
# 228          0.000000    A    0.1240    -8.062  Major       0.4010  144.011
# 282          0.000000    F    0.2380    -3.060  Minor       0.0448  119.901
# 289          0.000000    B    0.0929    -5.869  Major       0.0382  129.999
# 292          0.000000    E    0.3590    -4.580  Major       0.0471  119.901
# 314          0.000000   C#    0.3620    -3.641  Minor       0.3140  104.592
# 324          0.000010   F#    0.3940    -6.438  Minor       0.0972  154.823
# 328          0.884000   A#    0.2100   -10.527  Minor       0.0434   90.129
# 331          0.000010    E    0.2490    -3.445  Minor       0.0277  133.914
# 340          0.000005   F#    0.1110   -10.360  Minor       0.0360  108.287
# 346          0.000000    A    0.2920    -4.384  Major       1.2750   93.944
# 354          0.000019   G#    0.1110    -6.973  Major       0.1290   97.201
# 368          0.000000   C#    0.0696    -5.282  Major       0.0297  177.900
# 370          0.321000    G    0.2060    -9.986  Major       0.0328  161.600
# 374          0.872000    G    0.1160    -7.209  Minor       0.0414  179.474
# 379          0.000000   C#    0.2740    -8.693  Major       0.3800  130.128
# 384          0.684000    C    0.1120   -17.619  Major       0.0362  145.690
# 399          0.000170    E    0.1130    -6.779  Minor       0.0818  119.921
# 413          0.003460   C#    0.0395    -9.785  Major       0.0280  107.119
# 422          0.621000    F    0.2970    -3.478  Minor       0.0329   84.992
#
#      valence  music_genre
# 0     0.1880   Electronic
# 19    0.7620         Jazz
# 25    0.3160      Hip-Hop
# 27    0.3150      Hip-Hop
# 31    0.4600  Alternative
# 33    0.7690          Rap
# 43    0.8290  Alternative
# 46    0.5540         Rock
# 51    0.3130          Rap
# 56    0.8730      Country
# 66    0.8890      Hip-Hop
# 70    0.2230   Electronic
# 75    0.5660        Blues
# 88    0.0346    Classical
# 89    0.4920        Blues
# 96    0.1750        Anime
# 99    0.6790        Anime
# 109   0.3510          Rap
# 122   0.3480  Alternative
# 139   0.3090          Rap
# 151   0.8180          Rap
# 153   0.8610   Electronic
# 161   0.2540   Electronic
# 162   0.6120      Hip-Hop
# 175   0.4050          Rap
# 183   0.5050         Jazz
# 189   0.1190          Rap
# 203   0.4610         Jazz
# 213   0.1800  Alternative
# 214   0.1700   Electronic
# 221   0.6240  Alternative
# 228   0.2450      Hip-Hop
# 282   0.7390        Anime
# 289   0.8080      Country
# 292   0.3350  Alternative
# 314   0.4720          Rap
# 324   0.7260         Jazz
# 328   0.8570         Jazz
# 331   0.3980      Country
# 340   0.9330         Rock
# 346   0.6320          Rap
# 354   0.1770          Rap
# 368   0.5650         Rock
# 370   0.8240    Classical
# 374   0.8600         Jazz
# 379   0.2200          Rap
# 384   0.1660    Classical
# 399   0.1760      Country
# 413   0.9610         Rock
# 422   0.4200  Alternative

# %% [markdown]
# Тут какая-то ошибка в данных. Не может быть длина трека отрицательной.
# Данные обьекты мы удалим.

# %%
data_train = data_train.query('duration_ms > 0')

# %%
data_train.query('duration_ms > 500000').head(50)
# Out:
#       instance_id                                         track_name  \
# 201         45547  keyboard sonata no. 60 in c major, hob.xvi:50:...
# 233          1221                                            no_name
# 431         41640       scottish fantasy, op.46: 1. adagio cantabile
# 446         11289  alice in wonderland - take 2 / live at the vil...
# 452         50880                                              mural
# 710         45517  sibelius: violin concerto in d minor, op. 47: ...
# 740         32789                                sad and deep as you
# 790         42023  piano concerto no.4 in g, op.58: 1. allegro mo...
# 870         45955  mozart: piano concerto no. 25 in c major, k. 5...
# 885         44187  beethoven : symphony no.9 in d minor op.125 : ...
# 910         42573  piano concerto no. 2 in b-flat major, op. 83: ...
# 931         12204  little one - remastered 1999/rudy van gelder e...
# 944         44971                   symphony no. 1: i. allegro assai
# 959          3154                                            no_name
# 969         14400                                            no_name
# 1089        43734  the return of the king (feat. sir james galway...
# 1125         1894                                 giorgio by moroder
# 1134         4392                                    luminous beings
# 1336        15268                                            no_name
# 1376        12711                                            no_name
# 1385         4071                                           immunity
# 1405        44206  noches en los jardines de españa: i. en el gen...
# 1426         9038                                           epilogue
# 1441        44125                                            no_name
# 1558        44577                                           miserere
# 1566        11265                                        vein melter
# 1623         2375                                            no_name
# 1699        45397             romeo & juliet fantasy overture, th.42
# 1799        41757  violin concerto in d major, op. 61: i. allegro...
# 1840        42412                 piano trio in g, k.496: 1. allegro
# 1858         8024                                       afrika suite
# 1969        12258                                            chanson
# 2015        38899                how many more times - 1993 remaster
# 2029         2243                                 yr city's a sucker
# 2051        42734  concerto for flute and harp, k. 299; 2nd movement
# 2113        44495                                            no_name
# 2154        44328                                            no_name
# 2206        44937                                            no_name
# 2246        45513  symphony no. 5 in d minor, op. 47: i. moderato...
# 2257        33810                                       driving song
# 2285        45343  violin concerto no. 1 in g minor, op. 26: i. v...
# 2292        41536                                            no_name
# 2387         4031                        miracle d'hwange - original
# 2464        42452  symphonia domestica, op. 53, trv 209, pt. 2: f...
# 2506        32091  texas flood - live at ripley's music hall, phi...
# 2520        43132  violin concerto in a minor, op. 53, b. 108: ii...
# 2644        43841  serenade no. 1 in d major, op. 11: i. allegro ...
# 2670        43046       an der schönen blauen donau, walzer, op. 314
# 2687        34506                                            no_name
# 2740        35172  midnight in harlem (swamp raga intro with litt...
#
#       popularity  acousticness  danceability  duration_ms  energy  \
# 201         28.0      0.989000        0.3080     720627.0  0.1230
# 233         48.0      0.252000        0.8790     537164.0  0.7770
# 431         27.0      0.906000        0.2040     506091.0  0.1690
# 446         39.0      0.852000        0.4340     514533.0  0.2970
# 452         45.0      0.011000        0.4310     528880.0  0.8980
# 710         29.0      0.949000        0.0957     529387.0  0.1310
# 740         45.0      0.188000        0.3500     837160.0  0.3190
# 790         29.0      0.980000        0.3130    1157000.0  0.1170
# 870         45.0      0.985000        0.3000     540800.0  0.1090
# 885         64.0      0.964000        0.3640     822307.0  0.1890
# 910          0.0      0.987000        0.2930    1018613.0  0.1420
# 931         30.0      0.890000        0.4330     527267.0  0.3020
# 944         45.0      0.934000        0.2180     827840.0  0.1350
# 959         39.0      0.000733        0.2970     531578.0  0.4910
# 1089   0.0363   Classical
# 1125   0.4100  Electronic
# 1134   0.2000  Electronic
# 1336   0.3690        Jazz
# 1376   0.5520        Jazz
# 1385   0.0594  Electronic
# 1405   0.0358   Classical
# 1426   0.0711       Anime
# 1441   0.1940   Classical
# 1558   0.0323   Classical
# 1566   0.3890        Jazz
# 1623   0.2380  Electronic
# 1699   0.0362   Classical
# 1799   0.1890   Classical
# 1840   0.3960   Classical
# 1858   0.1930       Anime
# 1969   0.5480        Jazz
# 2015   0.5180        Rock
# 2029   0.8560  Electronic
# 2051   0.1840   Classical
# 2113   0.3860   Classical
# 2154   0.0491   Classical
# 2206   0.0396   Classical
# 2246   0.0362   Classical
# 2257   0.3380       Blues
# 2285   0.0602   Classical
# 2292   0.0774   Classical
# 2387   0.1610  Electronic
# 2464   0.0897   Classical
# 2506   0.4020       Blues
# 2520   0.2660   Classical
# 2644   0.0739   Classical
# 2670   0.1200   Classical
# 2687   0.4350       Blues
# 2740   0.2340       Blues

# %% [markdown]
# Опять классика. Похоже на правду. Оставляем.

# %% [markdown]
# ### 2.10 loudness

# %%
data_tempo.boxplot(column = 'loudness')
# Out:
# <Axes: >

# %%
print('Композиция с аномальными значениями длительности', len(data_train.loc[((data_train['loudness'] <= -60))]))
# Out:
# Композиция с аномальными значениями длительности 1314

# %%
data_train = data_train.query('loudness > -60')

# %% [markdown]
# ### 2.11 acousticness, energy, instrumentalness, liveness, speechiness, valence

# %%
data_train.boxplot(['acousticness', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'valence'])
# Out:
# <Axes: >

# %% [markdown]
# Значения по эти признакам должны быть в диапазоне от 0 до 1.
# Есть выбросы в speechiness. Удалим их.

# %%
data_train = data_train.query('0 < speechiness < 1')

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33489 entries, 1 to 39999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   instance_id       33489 non-null  int64
#  1   track_name        33489 non-null  object
#  2   popularity        33489 non-null  float64
#  3   acousticness      33489 non-null  float64
#  4   danceability      33489 non-null  float64
#  5   duration_ms       33489 non-null  float64
#  6   energy            33489 non-null  float64
#  7   instrumentalness  33489 non-null  float64
#  8   key               32299 non-null  object
#  9   liveness          33489 non-null  float64
#  10  loudness          33489 non-null  float64
#  11  mode              31944 non-null  object
#  12  speechiness       33489 non-null  float64
#  13  tempo             33489 non-null  float64
#  14  valence           33489 non-null  float64
#  15  music_genre       33489 non-null  object
# dtypes: float64(11), int64(1), object(4)
# memory usage: 4.3+ MB

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   instance_id       10000 non-null  int64
#  1   track_name        10000 non-null  object
#  2   popularity        10000 non-null  float64
#  3   acousticness      10000 non-null  float64
#  4   danceability      10000 non-null  float64
#  5   duration_ms       10000 non-null  float64
#  6   energy            10000 non-null  float64
#  7   instrumentalness  10000 non-null  float64
#  8   key               9673 non-null   object
#  9   liveness          10000 non-null  float64
#  10  loudness          10000 non-null  float64
#  11  mode              9518 non-null   object
#  12  speechiness       10000 non-null  float64
#  13  tempo             10000 non-null  float64
#  14  valence           10000 non-null  float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# **Промежуточный вывод**
#
# - Рассмотрены даты загрузки. Они были сделаны с 1 по 4 апреля. Эти данные не имеют статистической значимости, удалены из датасета.
#
# - Изучены пропуски в категориальных значениях
#   - track_name:
#
#    Приведены все названия в единый вид. Переведены в строчный регистр, убраны артикли и удалены лишние пробелы.
#
#   - key
#
#     Все корректно, 7 нот и 5 полутонов.
#
#      Больше всего треков в тональностях Соль и До. Меньше всего в Ре-Диез.
#
#   - mode
#
#     Здесь тоже все корректно 2 вида модальности и пропуски.
#
#     Треков в мажорной тональности почти в 2 раза больше.
#
#   - music genre
#
#     В наших данных для обучения содержится информация о 40000 треках. Это композиции в 10 жанрах. Данные распределены примерно одинаково, около 10% на каждый жанр.
#
# - изучены пропуски и выбросы в количественных значениях
#
#   - dancebility
#
#     Есть выбросы. Композиции с танцевальностью меньше 0.1.
#
#      Судя по названию, большинство таких композиций это классическая музыка и концерты. В таком случае, это информативная история. От таких выбросов избавляться не будем.
#
#     Пропуски заполнены медианным значением.
#
#   - popularity
#
#     Есть выбросы. Треки с популярностью больше 85 и меньше 0. Рассмотрим внимательнее.
#
#     Популярные Рэп, Рок, Хип-Хоп и электро композиции, оставляем. Менее популярные это классика.
#
#     Оставляем все объекты.
#
#     Пропуски заполняем медианным значением.
#
#   - tempo
#
#     Найдена ошибка.
#
#     Данные переведены в нужный формат.
#
#     Пропуски заполнены медианным значением.
#
#   - duration
#
#     Выявлены отрицательные значения. Не понятен характе ошибок. Данные объекты удалены.
#     Так же имееются выбросы, экстрадолгие композиции. судя по названиям это концерты симфонических оркестров.
#
#   - loudness
#
#     Удалены выбросы.
#
#   - acousticness, energy, instrumentalness, liveness, speechiness, valence
#
#     По условию данные признаки должны быть в пределах от 0 до 1.00.
#
#     Выбросы удалены.
#   Проверка на дубликаты
#
#    После удаление столбца с уникальным номером трека дубликаты не выявлены.

# %% [markdown]
# ## 3. Проверка на дубликаты

# %%
#Удалить первую строку
#data_phik = data_train.set_index('instance_id')
data_train = data_train.drop('instance_id', axis=1)

# %%
print(data_train.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ***Промежуточный вывод***
#
#
# После удаление столбца с уникальным номером трека дубликаты не выявлены.

# %% [markdown]
# ## 4. Кoрреляция признаков

# %%
data_train = data_train.drop('track_name', axis=1)
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33489 entries, 1 to 39999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   popularity        33489 non-null  float64
#  1   acousticness      33489 non-null  float64
#  2   danceability      33489 non-null  float64
#  3   duration_ms       33489 non-null  float64
#  4   energy            33489 non-null  float64
#  5   instrumentalness  33489 non-null  float64
#  6   key               32299 non-null  object
#  7   liveness          33489 non-null  float64
#  8   loudness          33489 non-null  float64
#  9   mode              31944 non-null  object
#  10  speechiness       33489 non-null  float64
#  11  tempo             33489 non-null  float64
#  12  valence           33489 non-null  float64
#  13  music_genre       33489 non-null  object
# dtypes: float64(11), object(3)
# memory usage: 3.8+ MB

# %%
phik_overview = data_train.phik_matrix()
phik_overview.round(2)
# Out:
# interval columns not set, guessing: ['popularity', 'acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence']
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/phik/phik.py:150: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_binned.replace(defs.UF, np.nan, inplace=True)
#                   popularity  acousticness  danceability  duration_ms  energy  \
# popularity              1.00          0.36          0.35         0.10    0.38
# acousticness            0.36          1.00          0.48         0.14    0.77
# danceability            0.35          0.48          1.00         0.16    0.54
# duration_ms             0.10          0.14          0.16         1.00    0.15
# energy                  0.38          0.77          0.54         0.15    1.00
# instrumentalness        0.37          0.48          0.36         0.16    0.47
# key                     0.07          0.10          0.10         0.02    0.10
# liveness                0.10          0.20          0.12         0.06    0.27
# loudness                0.38          0.72          0.50         0.17    0.84
# mode                    0.03          0.03          0.10         0.01    0.05
# speechiness             0.26          0.24          0.34         0.05    0.26
# tempo                   0.12          0.33          0.37         0.04    0.37
# valence                 0.21          0.43          0.56         0.14    0.51
# music_genre             0.77          0.67          0.63         0.19    0.68
#
#                   instrumentalness   key  liveness  loudness  mode  \
# popularity                    0.37  0.07      0.10      0.38  0.03
# acousticness                  0.48  0.10      0.20      0.72  0.03
# danceability                  0.36  0.10      0.12      0.50  0.10
# duration_ms                   0.16  0.02      0.06      0.17  0.01
# energy                        0.47  0.10      0.27      0.84  0.05
# instrumentalness              1.00  0.05      0.15      0.52  0.09
# key                           0.05  1.00      0.05      0.09  0.35
# liveness                      0.15  0.05      1.00      0.21  0.02
# loudness                      0.52  0.09      0.21      1.00  0.03
# mode                          0.09  0.35      0.02      0.03  1.00
# speechiness                   0.22  0.12      0.16      0.24  0.10
# tempo                         0.22  0.04      0.09      0.34  0.03
# valence                       0.38  0.05      0.15      0.47  0.04
# music_genre                   0.58  0.17      0.21      0.69  0.29
#
#                   speechiness  tempo  valence  music_genre
# popularity               0.26   0.12     0.21         0.77
# acousticness             0.24   0.33     0.43         0.67
# danceability             0.34   0.37     0.56         0.63
# duration_ms              0.05   0.04     0.14         0.19
# energy                   0.26   0.37     0.51         0.68
# instrumentalness         0.22   0.22     0.38         0.58
# key                      0.12   0.04     0.05         0.17
# liveness                 0.16   0.09     0.15         0.21
# loudness                 0.24   0.34     0.47         0.69
# mode                     0.10   0.03     0.04         0.29
# speechiness              1.00   0.19     0.15         0.52
# tempo                    0.19   1.00     0.26         0.32
# valence                  0.15   0.26     1.00         0.48
# music_genre              0.52   0.32     0.48         1.00

# %%
interval_cols = ['popularity', 'acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence']
phik_overview = data_train.phik_matrix(interval_cols=interval_cols)
# Out:
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/phik/phik.py:150: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_binned.replace(defs.UF, np.nan, inplace=True)

# %%
plot_correlation_matrix(phik_overview.values, 
                        x_labels=phik_overview.columns, 
                        y_labels=phik_overview.index, 
                        vmin=0, vmax=1, color_map="Greens", 
                        title=r"correlation $\phi_K$", 
                        fontsize_factor=1.5, 
                        figsize=(10, 8))

plt.show()

# %% [markdown]
# energy сильно коррелирует с loudness и acousticness.
# Пока удалять не будем

# %%
significance_overview = data_train.significance_matrix(interval_cols=interval_cols)
plot_correlation_matrix(significance_overview.fillna(0).values, 
                        x_labels=significance_overview.columns, 
                        y_labels=significance_overview.index, 
                        vmin=-5, vmax=5, title="Significance of the coefficients", 
                        usetex=False, fontsize_factor=1.5, figsize=(14, 10))
plt.show()
# Out:
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/phik/significance.py:328: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_binned.replace(defs.UF, np.nan, inplace=True)

# %% [markdown]
# ***Промежуточный вывод***
#
# Выявлена корреляция energy с loudness и acousticness.
# Удалять не будем

# %% [markdown]
# ## 5. Создание модели

# %%
#Выделяем целевой признак
X = data_train.drop(columns='music_genre')
y = data_train.music_genre

X.head()
# Out:
#    popularity  acousticness  danceability  duration_ms  energy  \
# 1        55.0        0.0647         0.282     288333.0  0.7380
# 2        39.0        0.9310         0.364     115240.0  0.3490
# 3        56.0        0.0123         0.332     234638.0  0.8470
# 4        52.0        0.5800         0.716     221640.0  0.6140
# 5        45.0        0.9940         0.299     267533.0  0.0319
#
#    instrumentalness  key  liveness  loudness   mode  speechiness    tempo  \
# 1          0.014200    C     0.290    -5.566  Major       0.0324  126.914
# 2          0.940000  NaN     0.110   -13.279    NaN       0.0321   65.427
# 3          0.000027    B     0.297    -4.513  Minor       0.0910   67.230
# 4          0.000014    G     0.160    -7.099  Major       0.0360   88.006
# 5          0.928000    D     0.105   -30.624  Major       0.0603  105.922
#
#    valence
# 1   0.2110
# 2   0.0891
# 3   0.3920
# 4   0.6800
# 5   0.0975

# %%
#Делим обучающую выборку на непосредственно обучающую и валидационную
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.25, random_state=state)

# %%
#Делим признаки на катгориальный и количественные
cat_columns = X.select_dtypes(include='object').columns.tolist()
num_columns = X.select_dtypes(include='float64').columns.tolist()
cat_columns
# Out:
# ['key', 'mode']

# %% [markdown]
# ### 5.1 Дерево решений

# %%
#Инициируем модель  
model = DecisionTreeClassifier(random_state=state)

# %%
#Прописываем column_transformer для обработки каждого типа данных
column_transformer = make_column_transformer((StandardScaler(), num_columns),
                                             (OneHotEncoder(drop='first'), cat_columns),
                                              remainder='passthrough')  

#Создаем pipeline в который будут входить и преобразователь и модель 
pipeline = make_pipeline(column_transformer, model)
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('standardscaler',
#                                                   StandardScaler(),
#                                                   ['popularity', 'acousticness',
#                                                    'danceability',
#                                                    'duration_ms', 'energy',
#                                                    'instrumentalness',
#                                                    'liveness', 'loudness',
#                                                    'speechiness', 'tempo',
#                                                    'valence']),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['key', 'mode'])])),
#                 ('decisiontreeclassifier',
#                  DecisionTreeClassifier(random_state=RandomState(MT19937) at 0x1788ED040))])

# %%
params = {
          'columntransformer__standardscaler': [StandardScaler(), MinMaxScaler()],
          'decisiontreeclassifier__max_depth':(1, 20, 2),
          'decisiontreeclassifier__min_samples_leaf': (2, 10, 1)
         }

# %%
gs = GridSearchCV(pipeline, params, cv=5)

# %%
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('standardscaler',
#                                                                          StandardScaler(),
#                                                                          ['popularity',
#                                                                           'acousticness',
#                                                                           'danceability',
#                                                                           'duration_ms',
#                                                                           'energy',
#                                                                           'instrumentalness',
#                                                                           'liveness',
#                                                                           'loudness',
#                                                                           'speechiness',
#                                                                           'tempo',
#                                                                           'valence']),
#                                                                         ('onehotencoder',
#                                                                          OneHotEncoder(drop='first'),
#                                                                          ['key',
#                                                                           'mode'])])),
#                                        ('decisiontreeclassifier',
#                                         DecisionTreeClassifier(random_state=RandomState(MT19937) at 0x1788ED040))]),
#              param_grid={'columntransformer__standardscaler': [StandardScaler(),
#                                                                MinMaxScaler()],
#                          'decisiontreeclassifier__max_depth': (1, 20, 2),
#                          'decisiontreeclassifier__min_samples_leaf': (2, 10,
#                                                                       1)})

# %%
gs.best_params_
# Out:
# {'columntransformer__standardscaler': StandardScaler(),
#  'decisiontreeclassifier__max_depth': 20,
#  'decisiontreeclassifier__min_samples_leaf': 10}

# %%
gs.best_score_
# Out:
# 0.4728853721923737

# %%
preds = gs.predict(X_valid)
print('f1_micro лучшей модели дерева решений:', f1_score(y_valid, preds, average='micro').round(2))
# Out:
# f1_micro лучшей модели дерева решений: 0.47

# %% [markdown]
# ### 5.2 Лес деревьев

# %%
model = RandomForestClassifier(random_state=state)
pipeline = make_pipeline(column_transformer, model)
pipeline.fit(X_train, y_train)
params = {
          'columntransformer__standardscaler': [StandardScaler(), MinMaxScaler()],
          'randomforestclassifier__n_estimators':(5, 35, 3),
          'randomforestclassifier__max_depth':(3, 15, 2),
          'randomforestclassifier__min_samples_leaf': (2, 5, 1)
         }

# %%
gs = GridSearchCV(pipeline, params, cv=5)

# %%
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('standardscaler',
#                                                                          StandardScaler(),
#                                                                          ['popularity',
#                                                                           'acousticness',
#                                                                           'danceability',
#                                                                           'duration_ms',
#                                                                           'energy',
#                                                                           'instrumentalness',
#                                                                           'liveness',
#                                                                           'loudness',
#                                                                           'speechiness',
#                                                                           'tempo',
#                                                                           'valence']),
#                                                                         ('onehotencoder',
#                                                                          OneHotEncoder(drop='first'),
#                                                                          ['key',
#                                                                           'mode'])])),
#                                        ('randomforestclassifier',
#                                         RandomForestClassifier(random_state=RandomState(MT19937) at 0x1788ED040))]),
#              param_grid={'columntransformer__standardscaler': [StandardScaler(),
#                                                                MinMaxScaler()],
#                          'randomforestclassifier__max_depth': (3, 15, 2),
#                          'randomforestclassifier__min_samples_leaf': (2, 5, 1),
#                          'randomforestclassifier__n_estimators': (5, 35, 3)})

# %%
gs.best_score_
# Out:
# 0.5480569158938945

# %%
gs.best_params_
# Out:
# {'columntransformer__standardscaler': StandardScaler(),
#  'randomforestclassifier__max_depth': 15,
#  'randomforestclassifier__min_samples_leaf': 5,
#  'randomforestclassifier__n_estimators': 35}

# %%
preds = gs.predict(X_valid)
print('f1_micro лучшей леса деревьев:', f1_score(y_valid, preds, average='micro').round(2))
# Out:
# f1_micro лучшей леса деревьев: 0.55

# %% [markdown]
# ### 5.3 Логистическая регрессия

# %%
model = LogisticRegression(random_state=state)
pipeline = make_pipeline(column_transformer, model)
pipeline.fit(X_train, y_train)
params = {
          'columntransformer__standardscaler': [StandardScaler(), MinMaxScaler()],
          'logisticregression__solver':['bfgs', 'sag', 'saga'],
          'logisticregression__max_iter' : (100, 500, 100)
}

# %%
gs = GridSearchCV(pipeline, params, cv=5)

# %%
gs.fit(X_train, y_train)
# Out:
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:542: FitFailedWarning:
# 30 fits failed out of a total of 90.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 890, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py", line 1351, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/pipeline.py", line 475, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "/Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py", line 1344, in wrapper
#     estimator._validate_params()
#   File "/Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'solver' parameter of LogisticRegression must be a str among {'lbfgs', 'liblinear', 'sag', 'newton-cholesky', 'saga', 'newton-cg'}. Got 'bfgs' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan 0.50995346 0.51007293        nan 0.50975437 0.50975437
#         nan 0.50995346 0.51007293        nan 0.5051755  0.50513568
#         nan 0.5051755  0.50513568        nan 0.5051755  0.50513568]
#   warnings.warn(
# /Users/mariaspartalan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('standardscaler',
#                                                                          StandardScaler(),
#                                                                          ['popularity',
#                                                                           'acousticness',
#                                                                           'danceability',
#                                                                           'duration_ms',
#                                                                           'energy',
#                                                                           'instrumentalness',
#                                                                           'liveness',
#                                                                           'loudness',
#                                                                           'speechiness',
#                                                                           'tempo',
#                                                                           'valence']),
#                                                                         ('onehotencoder',
#                                                                          OneHotEncoder(drop='first'),
#                                                                          ['key',
#                                                                           'mode'])])),
#                                        ('logisticregression',
#                                         LogisticRegression(random_state=RandomState(MT19937) at 0x1788ED040))]),
#              param_grid={'columntransformer__standardscaler': [StandardScaler(),
#                                                                MinMaxScaler()],
#                          'logisticregression__max_iter': (100, 500, 100),
#                          'logisticregression__solver': ['bfgs', 'sag', 'saga']})

# %%
gs.best_score_
# Out:
# 0.5100729320285919

# %%
gs.best_params_
# Out:
# {'columntransformer__standardscaler': StandardScaler(),
#  'logisticregression__max_iter': 100,
#  'logisticregression__solver': 'saga'}

# %%
preds = gs.predict(X_valid)
print('f1_micro лучшей логистической регрессии:', f1_score(y_valid, preds, average='micro').round(2))
# Out:
# f1_micro лучшей логистической регрессии: 0.51

# %% [markdown]
# ***Промежуточный вывод***
#
# - f1_micro лучшей модели дерева решений: 0.47
#
# - f1_micro лучшей модели леса деревьев: 0.55
#
# - f1_micro лучшей логистической регрессии: 0.51
#
#   Для предсказания значений на тестовой выборке мы используем модель Леса дереьвев с параметрами:
#
#  'columntransformer__standardscaler': StandardScaler(),
#  'randomforestclassifier__max_depth': 15,
#  'randomforestclassifier__min_samples_leaf': 5,
#  'randomforestclassifier__n_estimators': 35

# %% [markdown]
# ## 6. Предсказание значений на тестовой выборке

# %%
column_transformer = make_column_transformer((MinMaxScaler(), num_columns),
                                             (OneHotEncoder(drop='first'), cat_columns),
                                              remainder='passthrough')  
model = RandomForestClassifier(random_state=state, max_depth = 15, min_samples_leaf = 5, n_estimators = 35)
pipeline = make_pipeline(column_transformer, model)
pipeline.fit(X_train, y_train)
preds = pipeline.predict(data_test)
p = pd.DataFrame(data=preds)

# %%
p = p.rename(columns = {0: 'music_genre'})

# %%
predictions_final = pd.concat([data_test,p], axis=1)
predictions_final = predictions_final[['instance_id', 'music_genre']]
predictions_final.head()
# Out:
#    instance_id  music_genre
# 0        20514         Jazz
# 1        46957      Hip-Hop
# 2         5488   Electronic
# 3        18150  Alternative
# 4        20148  Alternative

# %%
predictions_final.to_csv('/Users/mariaspartalan/Desktop/готовые проекты/мифасоль/predictions_final.csv', index=False)

# %% [markdown]
# ### ОБЩИЙ ВЫВОД: ###
#
# Данные выгружены успешно.
# 40000 объектов в обучающей выборке и 10000 в тестовой.
#
# - Рассмотрены дату загрузки. Они были сделаны с 1 по 4 апреля. Эти данные не имеют статистической значимости, удалены из датасета.
#
# - Изучены пропуски в категориальных значениях
#   - track_name:
#
#    Приведены все названия в единый вид. Переведены в строчный регистр, убраны артикли и удалены лишние пробелы.
#
#   - key
#
#     Все корректно, 7 нот и 5 полутонов.
#
#      Больше всего треков в тональностях Соль и До. Меньше всего в Ре-Диез.
#
#   - mode
#
#     Здесь тоже все корректно 2 вида модальности и пропуски.
#
#     Треков в мажорной тональности почти в 2 раза больше.
#
#   - music genre
#
#     В наших данных для обучения содержится информация о 40000 треках. Это композиции в 10 жанрах. Данные распределены примерно одинаково, около 10% на каждый жанр.
#
# - изучены пропуски и выбросы в количественных значениях
#
#   - dancebility
#
#     Есть выбросы. Композиции с танцевальностью меньше 0.1.
#
#      Судя по названию, большинство таких композиций это классическая музыка и концерты. В таком случае, это информативная история. От таких выбросов избавляться не будем.
#
#     Пропуски заполнены медианным значением.
#
#   - popularity
#
#     Есть выбросы. Треки с популярностью больше 85 и меньше 0. Рассмотрим внимательнее.
#
#     Популярные Рэп, Рок, Хип-Хоп и электро композиции, оставляем. Менее популярные это классика.
#
#     Оставляем все объекты.
#
#     Пропуски заполняем медианным значением.
#
#   - tempo
#
#     Найдена ошибка.
#
#     Данные переведены в нужный формат.
#
#     Пропуски заполнены медианным значением.
#
#   - duration
#
#     Выявлены отрицательные значения. Не понятен характе ошибок. Данные объекты удалены.
#     Так же имееются выбросы, экстрадолгие композиции. судя по названиям это концерты симфонических оркестров.
#
#   - loudness
#
#     Удалены выбросы.
#
#   - acousticness, energy, instrumentalness, liveness, speechiness, valence
#
#     По условию данные признаки должны быть в пределах от 0 до 1.00.
#
#     Выбросы удалены.
#   Проверка на дубликаты
#
#    После удаление столбца с уникальным номером трека дубликаты не выявлены.
#
#
#    Выявлена корреляция energy с loudness и acousticness.
# Удалять не будем
#
#    Создан пайплайн, который анализирует признаки. Разделяет их по типу, кличественный масштабирует и категориальные кодирует. Далее на обработнных данных были обучены различные модели. Для каждой были подобраны оптимальные параметры. Проведена проверка качества работы с каждой по признаку f1_micro.
#
#   - f1_micro лучшей модели дерева решений: 0.47
#
#   - f1_micro лучшей модели леса деревьев: 0.55
#
#   - f1_micro лучшей логистической регрессии: 0.51
#
#   Для предсказания значений на тестовой выборке мы используем модель Леса дереьвев с параметрами:
#
#  'columntransformer__standardscaler': StandardScaler(),
#  'randomforestclassifier__max_depth': 15,
#  'randomforestclassifier__min_samples_leaf': 5,
#  'randomforestclassifier__n_estimators': 35
#
# ______________________________________
#
# Данная модель обработал тестовую выборку и предсказала жанры для треков. Данные предсказания сохранены в таблице predictions_final.
